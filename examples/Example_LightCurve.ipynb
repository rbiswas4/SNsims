# %%
import snsims

# %%
import sncosmo

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
data = sncosmo.load_example_data()

# %%
model = sncosmo.Model(source='salt2')

# %%
model.set(**data.meta)

# %%
print model
# Out:
# <Model at 0x110984910>
# source:
#   class      : SALT2Source
#   name       : 'salt2'
#   version    : 2.4
#   phases     : [-20, .., 50] days
#   wavelengths: [2000, .., 9200] Angstroms
# parameters:
#   z  = 0.5
#   t0 = 55100.0
#   x0 = 1.20482820761e-05
#   x1 = 0.5
#   c  = 0.20000000000000001

# %%
import seaborn as sns
sns.set()
# Out:
# /usr/local/software/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
fig = sncosmo.plot_lc(data, model=model, color='k')

# %%
lc = snsims.LightCurve(data.to_pandas())

# %%
sncosmo.plot_lc(lc.snCosmoLC(), model, color='k')
